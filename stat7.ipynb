# %% [markdown]
# # Biblioteki

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb

# %% [markdown]
# # Wczytanie z pliku

# %%
df = pd.read_csv("insuranceSAD.csv")
df
# Out:
#       Unnamed: 0  age     bmi  children  smoker      charges  female
# 0              0   19  27.900         0       1  16884.92400       1
# 1              1   18  33.770         1       0   1725.55230       0
# 2              2   28  33.000         3       0   4449.46200       0
# 3              3   33  22.705         0       0  21984.47061       0
# 4              4   32  28.880         0       0   3866.85520       0
# ...          ...  ...     ...       ...     ...          ...     ...
# 1333        1333   50  30.970         3       0  10600.54830       0
# 1334        1334   18  31.920         0       0   2205.98080       1
# 1335        1335   18  36.850         0       0   1629.83350       1
# 1336        1336   21  25.800         0       0   2007.94500       1
# 1337        1337   61  29.070         0       1  29141.36030       1
#
# [1338 rows x 7 columns]

# %%
df.head(3)
# Out:
#    Unnamed: 0  age    bmi  children  smoker     charges  female
# 0           0   19  27.90         0       1  16884.9240       1
# 1           1   18  33.77         1       0   1725.5523       0
# 2           2   28  33.00         3       0   4449.4620       0

# %%
df.tail(3)
# Out:
#       Unnamed: 0  age    bmi  children  smoker     charges  female
# 1335        1335   18  36.85         0       0   1629.8335       1
# 1336        1336   21  25.80         0       0   2007.9450       1
# 1337        1337   61  29.07         0       1  29141.3603       1

# %%
df.sample(3)
# Out:
#       Unnamed: 0  age    bmi  children  smoker     charges  female
# 1205        1205   35  17.86         1       0   5116.5004       0
# 759          759   18  38.17         0       1  36307.7983       0
# 679          679   49  23.18         2       0  10156.7832       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1338 non-null   int64
#  1   age         1338 non-null   int64
#  2   bmi         1338 non-null   float64
#  3   children    1338 non-null   int64
#  4   smoker      1338 non-null   int64
#  5   charges     1338 non-null   float64
#  6   female      1338 non-null   int64
# dtypes: float64(2), int64(5)
# memory usage: 73.3 KB

# %% [markdown]
# # Zadanie 1
# ## Punkt 2

# %%
df2 = df[["age","children","charges"]]
df2
# Out:
#       age  children      charges
# 0      19         0  16884.92400
# 1      18         1   1725.55230
# 2      28         3   4449.46200
# 3      33         0  21984.47061
# 4      32         0   3866.85520
# ...   ...       ...          ...
# 1333   50         3  10600.54830
# 1334   18         0   2205.98080
# 1335   18         0   1629.83350
# 1336   21         0   2007.94500
# 1337   61         0  29141.36030
#
# [1338 rows x 3 columns]

# %%
df2.describe()
# Out:
#                age     children       charges
# count  1338.000000  1338.000000   1338.000000
# mean     39.207025     1.094918  13270.422265
# std      14.049960     1.205493  12110.011237
# min      18.000000     0.000000   1121.873900
# 25%      27.000000     0.000000   4740.287150
# 50%      39.000000     1.000000   9382.033000
# 75%      51.000000     2.000000  16639.912515
# max      64.000000     5.000000  63770.428010

# %%
plt.hist(df["charges"],bins=10)
plt.ylabel("count")
plt.xlabel("value of charges")
# Out:
# Text(0.5, 0, 'value of charges')

# %%
fig, ax = plt.subplots(figsize=(16,7))
ax.boxplot(df["charges"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f338865d30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f344bd3310>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f338865a60>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f344bd38e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f344bd3bb0>],
#  'means': []}

# %%
plt.hist(df.loc[df["female"]==1,"charges"],alpha=0.5,label="female")
plt.hist(df.loc[df["female"]==0,"charges"],alpha=0.5,label="male")
plt.legend()

# %%
fig, ax2 = plt.subplots(figsize=(16,7))
ax2.boxplot([df.loc[df["female"]==0,"charges"],df.loc[df["female"]==1,"charges"]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f344cfb0d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f344cfb670>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f344cedb20>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1f344cfbc10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1f344cfbee0>,
# ...
#  'means': []}

# %%
plt.hist(df.loc[df["smoker"]==1,"charges"],alpha=0.5,label="smoker")
plt.hist(df.loc[df["smoker"]==0,"charges"],alpha=0.5,label="no smoker")
plt.legend()

# %%
fig, ax2 = plt.subplots(figsize=(16,7))
ax2.boxplot([df.loc[df["smoker"]==0,"charges"],df.loc[df["smoker"]==1,"charges"]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f344e00220>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f344e007c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f344df0ee0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1f344e00d60>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1f344e0e070>,
# ...
#  'means': []}

# %%
ax = sb.countplot(df["smoker"])
ax.legend(label=["no smoaker","smoaker"])
# Out:
# C:\Users\wikto\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_912\1021192529.py in <module>
#       1 ax = sb.countplot(df["smoker"])
# ----> 2 ax.legend(label=["no smoaker","smoaker"])
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     303         if len(extra_args):
# ...
